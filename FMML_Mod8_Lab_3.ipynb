# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanuprabhas/FMML-COURSE-ASSIGNMENTS/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-18 05:40:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   339MB/s    in 0.2s
#
# 2023-05-18 05:40:08 (339 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17612  1712.09509v1  Most previous approaches to Chinese word segme...    cs
# 10281   1103.0949v2  When dealing with time series with complex non...  stat
# 28828  1707.08385v1  Increased accuracy in predictive models for ha...    cs
# 16112  1609.08097v1  A common model for question answering (QA) is ...    cs
# 26554  1611.01982v2  OCR character segmentation for multilingual pr...    cs
# ...             ...                                                ...   ...
# 12441  1802.01737v1  Coherent uncertainty quantification is a key s...  stat
# 21613   1111.6160v1  We consider a standard binary classification p...  stat
# 17669  1801.07746v2  The science of happiness is an area of positiv...    cs
# 37549  1709.07080v1  In this paper we design and evaluate a Deep-Re...    cs
# 7714   1802.09902v2  Network pruning is aimed at imposing sparsity ...    cs
#
#                                                    title  year  \
# 17612  A Gap-Based Framework for Chinese Word Segment...  2017
# 10281  Adapting to Non-stationarity with Growing Expe...  2011
# 28828  A Novel Transfer Learning Approach upon Hindi,...  2017
# 16112  Creating Causal Embeddings for Question Answer...  2016
# 26554  Chinese/English mixed Character Segmentation a...  2016
# ...                                                  ...   ...
# 12441  Bayesian Coreset Construction via Greedy Itera...  2018
# 21613  Optimal exponential bounds on the accuracy of ...  2011
# 17669  HappyDB: A Corpus of 100,000 Crowdsourced Happ...  2018
# 37549  A Deep-Reinforcement Learning Approach for Sof...  2017
# 7714   Attention-Based Guided Structured Sparsity of ...  2018
#
#                                                 keywords
# 17612  [approaches, segmentation, classified, charact...
# 10281  [stationarities, retrospective, individual, re...
# 28828  [increased, predictive, handwritten, character...
# 16112  [answering, relatedness, determined, embedding...
# 26554  [character, segmentation, multilingual, docume...
# ...                                                  ...
# 12441  [uncertainty, quantification, algorithms, appr...
# 21613  [classification, performance, classifier, char...
# 17669  [happiness, psychology, concerned, understandi...
# 37549  [reinforcement, optimizes, automatically, cond...
# 7714   [architecture, increasing, regarding, efficien...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17612    [approaches, segmentation, classified, charact...
# 10281    [stationarities, retrospective, individual, re...
# 28828    [increased, predictive, handwritten, character...
# 16112    [answering, relatedness, determined, embedding...
# 26554    [character, segmentation, multilingual, docume...
#                                ...
# 21814    [principal, component, decomposable, graphical...
# 22932    [fundamental, distribution, transport, distrib...
# 1980     [significant, artificial, intelligence, applic...
# 34210    [spontaneous, conversations, interviews, ubiqu...
# 33759    [localization, localization, localization, ope...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8765 words.
# Out of those 4543 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="18910640-fb2b-48b4-aebc-5bee56055307" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18910640-fb2b-48b4-aebc-5bee56055307")) {                    Plotly.newPlot(                        "18910640-fb2b-48b4-aebc-5bee56055307",                        [{"x":["characters","convolutional","exploited","intuitive","outperforms","densenets","processing","implement","character","experiments","benchmarks","segmenting","conditional","segmentation","comparison","framework","classified","approaches","consecutive","therefore","plausible","genuinely","individual","expectation","algorithm","forecasters","stationary","available","algorithms","retrospective","guarantees","prospective","different","appropriate","evolutionary","stationarity","forecasts","stationarities","processes","ensembles","historical","realizations","drawbacks","languages","obstacles","backpropagation","handwritten","recognition","reduction","presenting","distribution","transferring","increased","predictive","knowledge","frontiers","overfitting","presented","minimized","performance","requirement","supervision","answering","determined","embeddings","embedding","information","causality","effectively","significantly","implication","outperforming","according","incorporate","bootstrapping","relatedness","reranking","explicitly","downstream","dedicated","indirectly","extracted","simulated","particularly","multilingual","documents","architecture","necessary","difficult","diversity","successful","synthesized","splitting","receptive","automatically","disturbance","reframing","linguistic","generalizes","horizontal","advantage","experimental","monolingual","preserves","variation","regularization","implementation","multiplier","objective","subjective","compressive","qualities","existence","lagrangian","effectiveness","reconstruction","recovered","campaigns","traditional","literature","marketing","investment","delivering","efficiently","opportunities","impressions","seasonality","important","purchasing","computational","specifically","improvements","technology","conversion","importantly","practical","introduce","statistically","definitions","inventory","shortcomings","summarization","platforms","requirements","optimization","environment","heterogeneous","conclusions","prediction","addresses","overlooked","advertisers","utilizing","experimentation","challenges","demonstrate","advertising","encounter","effective","evaluation","similarities","highlight","properties","applications","nonlinear","occurring","structured","frequently","additional","connections","adaptation","generalization","transport","couplings","illustrative","structure","techniques","prerequisite","designing","statistical","essential","correction","alternative","encountered","resourced","technique","processed","audiovisual","sequences","estimating","extensive","validation","deviations","directional","established","simplified","complication","clustering","submanifolds","riemannian"],"y":[27,387,26,27,274,2,283,71,56,601,89,15,100,207,145,572,26,387,11,144,17,0,125,30,775,1,21,282,608,3,67,1,756,75,51,4,4,0,115,16,14,1,19,101,12,38,28,350,91,15,240,15,36,70,349,2,29,168,7,927,43,57,71,35,83,122,692,9,121,285,6,25,97,62,12,6,1,59,12,22,7,108,64,80,16,71,241,78,134,42,62,24,11,20,174,2,3,73,27,6,100,379,9,16,69,79,122,6,171,21,18,7,27,10,201,93,13,4,175,129,5,3,4,152,15,5,1,406,3,283,177,104,48,13,27,129,335,25,20,6,14,31,33,51,319,135,39,22,231,52,8,3,46,17,120,519,8,6,255,262,24,24,230,443,58,20,97,22,106,52,66,113,10,1,10,338,374,6,41,172,50,23,82,13,4,276,28,2,79,70,184,50,9,12,51,22,2,137,1,8],"type":"bar"},{"x":["characters","convolutional","exploited","intuitive","outperforms","densenets","processing","implement","character","exp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4543,), (4543, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>GPU</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>Pedestrian</span> <span style='background-color:rgba(0, 255, 0, 0.5328798185941044);'>Detection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6507936507936507);'>Autonomous</span> <span style=''>Driving</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>pedestrian</span> <span style='background-color:rgba(0, 255, 0, 0.5328798185941044);'>detection</span> <span style=''>system</span> <span style=''>for</span> <span style=''>the</span> <span style=''>embedded</span> <span style=''>Nvidia</span> <span style=''>Tegra</span> <span style=''>X1</span> <span style=''>GPU</span> <span style=''>CPU</span> <span style=''>hybrid</span> <span style=''>platform</span> <span style=''>The</span> <span style=''>pipeline</span> <span style=''>is</span> <span style=''>composed</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>Histogram</span> <span style=''>of</span> <span style=''>Local</span> <span style=''>Binary</span> <span style=''>Patterns</span> <span style=''>(LBP)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Histograms</span> <span style=''>of</span> <span style=''>Oriented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Gradients</span> <span style=''>(HOG)</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043478);'>extracted</span> <span style=''>from</span> <span style=''>the</span> <span style=''>input</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>Pyramidal</span> <span style=''>Sliding</span> <span style=''>Window</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>candidate</span> <span style='background-color:rgba(0, 255, 0, 0.5911602209944751);'>generation</span> <span style=''>and</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(SVM)</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Results</span> <span style=''>show</span> <span style=''>a</span> <span style=''>8x</span> <span style=''>speedup</span> <span style=''>in</span> <span style=''>the</span> <span style=''>target</span> <span style=''>Tegra</span> <span style=''>X1</span> <span style=''>platform</span> <span style=''>and</span> <span style=''>a</span> <span style=''>better</span> <span style=''>performancewatt</span> <span style=''>ratio</span> <span style=''>than</span> <span style=''>desktop</span> <span style=''>CUDA</span> <span style='background-color:rgba(0, 255, 0, 0.736842105263158);'>platforms</span> <span style=''>in</span> <span style=''>study</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>UPAL</span> <span style=''>Unbiased</span> <span style=''>Pool</span> <span style=''>Based</span> <span style=''>Active</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>pool</span> <span style=''>based</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>UPAL</span> <span style=''>that</span> <span style=''>works</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style=''>unbiased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>of</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>space</span> <span style=''>For</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>the</span> <span style=''>squared</span> <span style=''>loss</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>UPAL</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>weighted</span> <span style=''>average</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecaster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exploiting</span> <span style=''>some</span> <span style=''>recent</span> <span style=''>results</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style=''>spectra</span> <span style=''>of</span> <span style=''>random</span> <span style=''>matrices</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>UPAL</span> <span style=''>when</span> <span style=''>the</span> <span style=''>true</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>is</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style=''>an</span> <span style=''>active</span> <span style=''>learner</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>in</span> <span style=''>Vowpal</span> <span style=''>Wabbit</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>proposed</span> <span style=''>pool</span> <span style=''>based</span> <span style=''>active</span> <span style=''>learner</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>show</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Filtering</span> <span style=''>Additive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Measurement</span> <span style=''>Noise</span> <span style=''>with</span> <span style=''>Maximum</span> <span style=''>Entropy</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Mean</span> <br/><br/><span style=''>The</span> <span style=''>purpose</span> <span style=''>of</span> <span style=''>this</span> <span style=''>note</span> <span style=''>is</span> <span style=''>to</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>method</span> <span style=''>of</span> <span style=''>maximum</span> <span style=''>entropy</span> <span style=''>in</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>(MEM)</span> <span style=''>may</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.4625);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style=''>by</span> <span style=''>large</span> <span style=''>level</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>on</span> <span style=''>a</span> <span style=''>concrete</span> <span style=''>example</span> <span style=''>that</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>with</span> <span style=''>the</span> <span style=''>bayesian</span> <span style=''>and</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5169811320754716);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Geometry</span> <span style=''>and</span> <span style=''>Dynamics</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <br/><br/><span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>revolutionised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>and</span> <span style=''>enabled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>within</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>context</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>dynamics</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>way</span> <span style=''>of</span> <span style=''>building</span> <span style=''>chains</span> <span style=''>which</span> <span style=''>can</span> <span style=''>explore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>densities</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>The</span> <span style=''>method</span> <span style=''>emerges</span> <span style=''>from</span> <span style=''>physics</span> <span style=''>and</span> <span style=''>geometry</span> <span style=''>and</span> <span style=''>these</span> <span style=''>links</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>studied</span> <span style=''>by</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style=''>authors</span> <span style=''>through</span> <span style=''>the</span> <span style=''>last</span> <span style=''>thirty</span> <span style=''>years</span> <span style=''>However</span> <span style=''>there</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>a</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>users</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>and</span> <span style=''>our</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundations</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>review</span> <span style=''>is</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduction</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>tool ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0688802543270929)
# 	knowledge (0.12327799364182268)
# 	representation (0.12716354645001765)
# 	architecture (0.08512892970681737)
# 	information (0.24443659484281172)
# 	segmentation (0.07311903920876016)
# 	detection (0.1193924408336277)
# 	different (0.2670434475450371)
# 	recognition (0.12363122571529495)
# 	convolutional (0.136700812433769)
#
# Some Statistics words are:
# 	variables (0.12392077196546471)
# 	theoretical (0.1579481970543423)
# 	distribution (0.1792788217369223)
# 	stochastic (0.13915693245302183)
# 	estimation (0.17572371762315897)
# 	statistical (0.16556627729812087)
# 	inference (0.19451498222447944)
# 	dimensional (0.18689690198070086)
# 	algorithm (0.40731335703402743)
# 	regression (0.18334179786693752)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="278877b0-331c-4c92-b7ae-a2bed1466dc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("278877b0-331c-4c92-b7ae-a2bed1466dc3")) {                    Plotly.newPlot(                        "278877b0-331c-4c92-b7ae-a2bed1466dc3",                        [{"x":["characters","convolutional","exploited","intuitive","outperforms","densenets","processing","implement","character","experiments","benchmarks","segmenting","conditional","segmentation","comparison","framework","classified","approaches","consecutive","therefore","plausible","genuinely","individual","expectation","algorithm","forecasters","stationary","available","algorithms","retrospective","guarantees","prospective","different","appropriate","evolutionary","stationarity","forecasts","stationarities","processes","ensembles","historical","realizations","drawbacks","languages","obstacles","backpropagation","handwritten","recognition","reduction","presenting","distribution","transferring","increased","predictive","knowledge","frontiers","overfitting","presented","minimized","performance","requirement","supervision","answering","determined","embeddings","embedding","information","causality","effectively","significantly","implication","outperforming","according","incorporate","bootstrapping","relatedness","reranking","explicitly","downstream","dedicated","indirectly","extracted","simulated","particularly","multilingual","documents","architecture","necessary","difficult","diversity","successful","synthesized","splitting","receptive","automatically","disturbance","reframing","linguistic","generalizes","horizontal","advantage","experimental","monolingual","preserves","variation","regularization","implementation","multiplier","objective","subjective","compressive","qualities","existence","lagrangian","effectiveness","reconstruction","recovered","campaigns","traditional","literature","marketing","investment","delivering","efficiently","opportunities","impressions","seasonality","important","purchasing","computational","specifically","improvements","technology","conversion","importantly","practical","introduce","statistically","definitions","inventory","shortcomings","summarization","platforms","requirements","optimization","environment","heterogeneous","conclusions","prediction","addresses","overlooked","advertisers","utilizing","experimentation","challenges","demonstrate","advertising","encounter","effective","evaluation","similarities","highlight","properties","applications","nonlinear","occurring","structured","frequently","additional","connections","adaptation","generalization","transport","couplings","illustrative","structure","techniques","prerequisite","designing","statistical","essential","correction","alternative","encountered","resourced","technique","processed","audiovisual","sequences","estimating","extensive","validation","deviations","directional","established","simplified","complication","clustering","submanifolds","riemannian","intersect","constructs","thoroughly","geodesics","computationally","intrinsic","identification","application","underlying","advocates","grassmannian","dimensional","synthetic","exploiting","theoretical","demonstrates","efficient","inference","interesting","continuous","parameter","stochastic","correlates","resulting","parameters","variables","furthermore","intelligently","gradients","parallelized","blackwellized","variational","constructing","performing","trivially","decisions","beneficial","identifying","educational","empirical","stopwords","improvement","probabilistic","considers","irrelevant","correlation","significant","difficulty","probability","mathematical","classifier","independent","calculating","classification","categorization","sentences","supe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	genuinely
# 	stationarities
# 	geodesics
# 	blackwellized
# 	coincides
# 	staleness
# 	heteroscedasticity
# 	psychiatric
# 	integrands
# 	bivariate
# 	amortization
# 	backpropagating
# 	penalization
# 	subdifferential
# 	covariates
# 	distributionally
# 	unattainable
# 	infection
# 	safeguard
# 	decomposability
# Some words which never appear in Statistics papers:
# 	densenets
# 	transferring
# 	disturbance
# 	campaigns
# 	impressions
# 	resourced
# 	stopwords
# 	operationalization
# 	disruption
# 	incidents
# 	compliance
# 	detections
# 	compounding
# 	referenced
# 	utterance
# 	articulated
# 	localizing
# 	prescriptions
# 	interference
# 	prescription

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0438620521717955e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7325
